# %% [markdown]
# <a href="https://www.kaggle.com/code/moazawadali/rnn-for-next-word-prediction?scriptVersionId=236702317" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt
# Out:
# 2025-04-28 22:36:51.651905: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745879811.852490      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745879811.918047      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
text = """
once upon a time there was a little girl who lived in a village near the forest
she liked to wear a red coat with a hood that her grandmother had made for her
everyone in the village called her little red riding hood one morning her mother asked
her to visit grandmother who lived in the forest but warned her not to talk to strangers
on her way little red riding hood met a wolf who asked where she was going
the girl told the wolf about her grandmother who lived alone in the forest
the wolf ran ahead to the grandmother house and pretended to be the little girl
when little red riding hood arrived the wolf was waiting in the bed disguised as grandmother
little red riding hood noticed something strange about her grandmother and said what big eyes you have
the wolf replied all the better to see you with my dear
"""

# %%
text = text.lower().replace('\n', ' ')
words = [word for word in text.split() if word.isalnum()]

print(f"Total words in the corpus: {len(words)}")
print(f"First 10 words: {words[:10]}")
# Out:
# Total words in the corpus: 156
# First 10 words: ['once', 'upon', 'a', 'time', 'there', 'was', 'a', 'little', 'girl', 'who']

# %%
sequences = []
for i in range(len(words) - 3):
    sequences.append(words[i:i+4])

print(f"Number of sequences: {len(sequences)}")
print(f"First 3 sequences: {sequences[:3]}")
# Out:
# Number of sequences: 153
# First 3 sequences: [['once', 'upon', 'a', 'time'], ['upon', 'a', 'time', 'there'], ['a', 'time', 'there', 'was']]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([' '.join(words)])
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # +1 for the padding token

print(f"Vocabulary size: {vocab_size}")
print(f"Sample from vocabulary: {list(word_index.items())[:5]}")
# Out:
# Vocabulary size: 79
# Sample from vocabulary: [('the', 1), ('her', 2), ('to', 3), ('a', 4), ('little', 5)]

# %%
X = []  # input sequences (first 3 words)
y = []  # target word (4th word)

for seq in sequences:
    X.append(seq[:3])
    y.append(seq[3])

print(f"X shape: {len(X)} sequences of length 3")
print(f"y shape: {len(y)} words")
print(f"Sample X: {X[:3]}")
print(f"Sample y: {y[:3]}")
# Out:
# X shape: 153 sequences of length 3
# y shape: 153 words
# Sample X: [['once', 'upon', 'a'], ['upon', 'a', 'time'], ['a', 'time', 'there']]
# Sample y: ['time', 'there', 'was']

# %%
X_seq = tokenizer.texts_to_sequences([' '.join(seq) for seq in X])
y_seq = tokenizer.texts_to_sequences([word for word in y])

# %%
y_seq = [item[0] for item in y_seq]

print(f"First 3 X sequences (encoded): {X_seq[:3]}")
print(f"First 3 y values (encoded): {y_seq[:3]}")
# Out:
# First 3 X sequences (encoded): [[24, 25, 4], [25, 4, 26], [4, 26, 27]]
# First 3 y values (encoded): [26, 27, 13]

# %%
X_array = np.array(X_seq)
y_array = np.array(y_seq)

print(f"X shape: {X_array.shape}")
print(f"y shape: {y_array.shape}")
# Out:
# X shape: (153, 3)
# y shape: (153,)

# %%
y_one_hot = tf.keras.utils.to_categorical(y_array, num_classes=vocab_size)
print(f"y one-hot shape: {y_one_hot.shape}")
# Out:
# y one-hot shape: (153, 79)

# %%
embedding_dim = 50
lstm_units = 100

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9382 - loss: 0.5988 - val_accuracy: 0.1290 - val_loss: 6.4207
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9309 - loss: 0.6105 - val_accuracy: 0.1290 - val_loss: 6.4487
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9437 - loss: 0.5485 - val_accuracy: 0.1290 - val_loss: 6.4724
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9354 - loss: 0.5914 - val_accuracy: 0.1290 - val_loss: 6.5026
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9355 - loss: 0.5510 - val_accuracy: 0.1290 - val_loss: 6.5294
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9657 - loss: 0.5065 - val_accuracy: 0.1290 - val_loss: 6.5557
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9596 - loss: 0.4987 - val_accuracy: 0.1290 - val_loss: 6.5731
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9711 - loss: 0.4627 - val_accuracy: 0.1290 - val_loss: 6.5849
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9513 - loss: 0.4786 - val_accuracy: 0.1290 - val_loss: 6.6102
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9690 - loss: 0.4122 - val_accuracy: 0.1290 - val_loss: 6.6242
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9669 - loss: 0.4130 - val_accuracy: 0.1290 - val_loss: 6.6388
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9555 - loss: 0.3955 - val_accuracy: 0.1290 - val_loss: 6.6528
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9565 - loss: 0.4016 - val_accuracy: 0.1290 - val_loss: 6.6709
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9460 - loss: 0.3684 - val_accuracy: 0.1290 - val_loss: 6.6824
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9418 - loss: 0.3785 - val_accuracy: 0.1290 - val_loss: 6.6953
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9701 - loss: 0.3674 - val_accuracy: 0.1290 - val_loss: 6.7121
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9659 - loss: 0.3465 - val_accuracy: 0.1290 - val_loss: 6.7285
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9555 - loss: 0.3563 - val_accuracy: 0.1290 - val_loss: 6.7509
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9711 - loss: 0.3230 - val_accuracy: 0.1290 - val_loss: 6.7602
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9711 - loss: 0.3142 - val_accuracy: 0.1290 - val_loss: 6.7707
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9595 - loss: 0.3104 - val_accuracy: 0.1290 - val_loss: 6.7782
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9460 - loss: 0.3163 - val_accuracy: 0.1290 - val_loss: 6.7939
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9659 - loss: 0.2916 - val_accuracy: 0.1290 - val_loss: 6.7972
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9440 - loss: 0.2973 - val_accuracy: 0.1290 - val_loss: 6.8032
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9711 - loss: 0.2446 - val_accuracy: 0.1290 - val_loss: 6.8103
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9690 - loss: 0.2525 - val_accuracy: 0.1290 - val_loss: 6.8177
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9440 - loss: 0.2730 - val_accuracy: 0.1290 - val_loss: 6.8312

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Cell 1: Import necessary libraries
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import matplotlib.pyplot as plt

# Cell 2: Define the sample text corpus
text = """
once upon a time there was a little girl who lived in a village near the forest
she liked to wear a red coat with a hood that her grandmother had made for her
everyone in the village called her little red riding hood one morning her mother asked
her to visit grandmother who lived in the forest but warned her not to talk to strangers
on her way little red riding hood met a wolf who asked where she was going
the girl told the wolf about her grandmother who lived alone in the forest
the wolf ran ahead to the grandmother house and pretended to be the little girl
when little red riding hood arrived the wolf was waiting in the bed disguised as grandmother
little red riding hood noticed something strange about her grandmother and said what big eyes you have
the wolf replied all the better to see you with my dear
"""

# Cell 3: Clean and tokenize the text
# Clean the text
text = text.lower().replace('\n', ' ')
words = [word for word in text.split() if word.isalnum()]

print(f"Total words in the corpus: {len(words)}")
print(f"First 10 words: {words[:10]}")

# Cell 4: Create sequences of 4 words
sequences = []
for i in range(len(words) - 3):
    sequences.append(words[i:i+4])

print(f"Number of sequences: {len(sequences)}")
print(f"First 3 sequences: {sequences[:3]}")

# Cell 5: Create the vocabulary and convert words to indices
tokenizer = Tokenizer()
tokenizer.fit_on_texts([' '.join(words)])
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1  # +1 for the padding token

print(f"Vocabulary size: {vocab_size}")
print(f"Sample from vocabulary: {list(word_index.items())[:5]}")

# Cell a6: Create input sequences and target words
X = []  # input sequences (first 3 words)
y = []  # target word (4th word)

for seq in sequences:
    X.append(seq[:3])
    y.append(seq[3])

print(f"X shape: {len(X)} sequences of length 3")
print(f"y shape: {len(y)} words")
print(f"Sample X: {X[:3]}")
print(f"Sample y: {y[:3]}")

# Cell 7: Convert word sequences to integer sequences
X_seq = tokenizer.texts_to_sequences([' '.join(seq) for seq in X])
y_seq = tokenizer.texts_to_sequences([word for word in y])

# Flatten the y_seq (it's a list of lists)
y_seq = [item[0] for item in y_seq]

print(f"First 3 X sequences (encoded): {X_seq[:3]}")
print(f"First 3 y values (encoded): {y_seq[:3]}")

# Cell 8: Convert to numpy arrays
X_array = np.array(X_seq)
y_array = np.array(y_seq)

print(f"X shape: {X_array.shape}")
print(f"y shape: {y_array.shape}")

# Cell 9: Create one-hot encoded targets
y_one_hot = tf.keras.utils.to_categorical(y_array, num_classes=vocab_size)
print(f"y one-hot shape: {y_one_hot.shape}")

# Cell 10: Build the RNN model
embedding_dim = 50
lstm_units = 100

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=embedding_dim, input_length=3),
    LSTM(units=lstm_units),
    Dense(units=vocab_size, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()

# Cell 11: Train the model
history = model.fit(
    X_array, y_one_hot,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# Cell 12: Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='lower right')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')

plt.tight_layout()
plt.show()

# Cell 13: Function to predict the next word
def predict_next_word(input_text):
    # Clean and tokenize the input text
    words = input_text.lower().split()
    
    # Check if we have exactly 3 words
    if len(words) != 3:
        return "Please provide exactly 3 words as input."
    
    # Check if all words are in the vocabulary
    for word in words:
        if word not in word_index:
            return f"Word '{word}' is not in the vocabulary. Please try another word."
    
    # Convert to sequence
    seq = tokenizer.texts_to_sequences([input_text])[0]
    
    # Make prediction
    prediction = model.predict(np.array([seq]))
    predicted_index = np.argmax(prediction)
    
    # Get the word from the index
    for word, index in word_index.items():
        if index == predicted_index:
            return word
    
    return "Could not find the predicted word in the vocabulary."
# Out:
# Total words in the corpus: 156
# First 10 words: ['once', 'upon', 'a', 'time', 'there', 'was', 'a', 'little', 'girl', 'who']
# Number of sequences: 153
# First 3 sequences: [['once', 'upon', 'a', 'time'], ['upon', 'a', 'time', 'there'], ['a', 'time', 'there', 'was']]
# Vocabulary size: 79
# Sample from vocabulary: [('the', 1), ('her', 2), ('to', 3), ('a', 4), ('little', 5)]
# X shape: 153 sequences of length 3
# y shape: 153 words
# Sample X: [['once', 'upon', 'a'], ['upon', 'a', 'time'], ['a', 'time', 'there']]
# Sample y: ['time', 'there', 'was']
# First 3 X sequences (encoded): [[24, 25, 4], [25, 4, 26], [4, 26, 27]]
# First 3 y values (encoded): [26, 27, 13]
# X shape: (153, 3)
# y shape: (153,)
# y one-hot shape: (153, 79)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9531 - loss: 0.5363 - val_accuracy: 0.0645 - val_loss: 6.5042
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9385 - loss: 0.5227 - val_accuracy: 0.0645 - val_loss: 6.5205
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9489 - loss: 0.4890 - val_accuracy: 0.0645 - val_loss: 6.5414
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9501 - loss: 0.4578 - val_accuracy: 0.0645 - val_loss: 6.5671
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9501 - loss: 0.4683 - val_accuracy: 0.0645 - val_loss: 6.5902
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9543 - loss: 0.4210 - val_accuracy: 0.0645 - val_loss: 6.6140
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9573 - loss: 0.4131 - val_accuracy: 0.0645 - val_loss: 6.6264
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9512 - loss: 0.3802 - val_accuracy: 0.0645 - val_loss: 6.6467
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9333 - loss: 0.3922 - val_accuracy: 0.0645 - val_loss: 6.6714
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9449 - loss: 0.3653 - val_accuracy: 0.0645 - val_loss: 6.6890
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9342 - loss: 0.3736 - val_accuracy: 0.0645 - val_loss: 6.7127
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9269 - loss: 0.3337 - val_accuracy: 0.0645 - val_loss: 6.7220
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9446 - loss: 0.3261 - val_accuracy: 0.0645 - val_loss: 6.7266
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9512 - loss: 0.3224 - val_accuracy: 0.0645 - val_loss: 6.7414
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9418 - loss: 0.3245 - val_accuracy: 0.0645 - val_loss: 6.7547
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9564 - loss: 0.2952 - val_accuracy: 0.0645 - val_loss: 6.7766
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9312 - loss: 0.3065 - val_accuracy: 0.0645 - val_loss: 6.7974
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9574 - loss: 0.2867 - val_accuracy: 0.0645 - val_loss: 6.8090
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9513 - loss: 0.2900 - val_accuracy: 0.0645 - val_loss: 6.8237
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9534 - loss: 0.2811 - val_accuracy: 0.0645 - val_loss: 6.8336
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9657 - loss: 0.2524 - val_accuracy: 0.0645 - val_loss: 6.8376
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9657 - loss: 0.2524 - val_accuracy: 0.0645 - val_loss: 6.8467
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9649 - loss: 0.2260 - val_accuracy: 0.0645 - val_loss: 6.8548
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9503 - loss: 0.2595 - val_accuracy: 0.0645 - val_loss: 6.8748
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9626 - loss: 0.2429 - val_accuracy: 0.0645 - val_loss: 6.8983
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9303 - loss: 0.2430 - val_accuracy: 0.0645 - val_loss: 6.9113

# %%
test_inputs = [
    "once upon a",
    "little red riding",
    "in the forest",
    "she liked to"
]

for input_text in test_inputs:
    predicted_word = predict_next_word(input_text)
    print(f"Input: '{input_text}'")
    print(f"Predicted next word: '{predicted_word}'")
    print(f"Complete sequence: '{input_text} {predicted_word}'")
    print("-" * 50)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# Input: 'once upon a'
# Predicted next word: 'time'
# Complete sequence: 'once upon a time'
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Input: 'little red riding'
# Predicted next word: 'hood'
# Complete sequence: 'little red riding hood'
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Input: 'in the forest'
# Predicted next word: 'the'
# Complete sequence: 'in the forest the'
# --------------------------------------------------
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Input: 'she liked to'
# Predicted next word: 'wear'
# Complete sequence: 'she liked to wear'
# --------------------------------------------------

# %%
user_input = "girl told the"
predicted_word = predict_next_word(user_input)
print(f"Predicted next word: '{predicted_word}'")
print(f"Complete sequence: '{user_input} {predicted_word}'")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Predicted next word: 'wolf'
# Complete sequence: 'girl told the wolf'
